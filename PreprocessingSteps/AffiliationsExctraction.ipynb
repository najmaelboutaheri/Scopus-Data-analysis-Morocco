# %% [markdown]
# ## **INTRODUCTION:**

# %% [markdown]
# This notebook is about processing data to exctract the exact name of affiliations:
#
# The steps to follow in this notebook are :
#
#
# ---
#
#
# **STEP 1:**
# 1. Exctract the moroccan affiliations based on 'Morocco' country.
# 2. Exctract  affiliations based on 'University' word including this word in diffrent languages using the following regular expression:
# ```
# pattern = re.compile(r"([^,]*?)\s*(university|université|universidad|universiti)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)
# ```
# 3. Exctract 'Unkown' affiliations then apply the following regular expression:
# ```
# pattern = re.compile(r"([^,]*?)\s*(institute|institut|academy|school|college|polytechnic|center|centre|centro|conservatory|organization|corporation|association|Hospital)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)
# ```
#
#
# ---
#
#
# **STEP 2:**
# 1. Exctract non moroccan affiliations based on 'Morocco' country means whene country != 'Morocco'.
# 2. Exctract  affiliations based on 'University' word including this word in diffrent languages using the following regular expression:
# ```
# pattern = re.compile(r"([^,]*?)\s*(university|université|universidad|universiti)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)
# ```
# 3. Exctract 'Unkown' affiliations then apply the following regular expression:
# ```
# pattern = re.compile(r"([^,]*?)\s*(institute|institut|academy|school|college|polytechnic|center|centre|centro|conservatory|organization|corporation|association|Hospital)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)
# ```

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import re

# %% [markdown]
# ## **STEP 1:**

# %% [markdown]
# **1. Exctract the moroccan affiliations based on 'Morocco' country.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_affiliation_author=pd.read_csv('/content/drive/MyDrive/data2024/affiliation-author.csv')

# %%
data_affiliation_author
# Out:
#                                                 affiliation          author  \
# 0         Département de Cardiologie, Hôpital Universita...        Rahmi M.
# 1         Département de Cardiologie, Hôpital Universita...      Merzouk F.
# 2         Département de Cardiologie, Hôpital Universita...  El Ouarradi A.
# 3         Département de Cardiologie, Hôpital Universita...       Habbal R.
# 4         College of Engineering and Technology, America...       Sabbah H.
# ...                                                     ...             ...
# 10432494  School of Plant Biology, Faculty of Science, T...        Bitew B.
# 10432495  School of Plant Biology, Faculty of Science, T...      Fininsa C.
# 10432496  School of Plant Biology, Faculty of Science, T...       Terefe H.
# 10432497  School of Plant Biology, Faculty of Science, T...     Barbetti M.
# 10432498  School of Plant Biology, Faculty of Science, T...        Ahmed S.
#
#           affiliation_id
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      2
# ...                  ...
# 10432494           44607
# 10432495           44607
# 10432496           44607
# 10432497           44607
# 10432498           44607
#
# [10432499 rows x 3 columns]

# %%
data_affiliation_author= data_affiliation_author.fillna('').astype(str)

# %%
data_affiliation_author
# Out:
#                                                 affiliation          author  \
# 0         Département de Cardiologie, Hôpital Universita...        Rahmi M.
# 1         Département de Cardiologie, Hôpital Universita...      Merzouk F.
# 2         Département de Cardiologie, Hôpital Universita...  El Ouarradi A.
# 3         Département de Cardiologie, Hôpital Universita...       Habbal R.
# 4         College of Engineering and Technology, America...       Sabbah H.
# ...                                                     ...             ...
# 10432494  School of Plant Biology, Faculty of Science, T...        Bitew B.
# 10432495  School of Plant Biology, Faculty of Science, T...      Fininsa C.
# 10432496  School of Plant Biology, Faculty of Science, T...       Terefe H.
# 10432497  School of Plant Biology, Faculty of Science, T...     Barbetti M.
# 10432498  School of Plant Biology, Faculty of Science, T...        Ahmed S.
#
#          affiliation_id
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     2
# ...                 ...
# 10432494          44607
# 10432495          44607
# 10432496          44607
# 10432497          44607
# 10432498          44607
#
# [10432499 rows x 3 columns]

# %%
# Filter rows that contain "Morocco" to target Moroccan affiliations
moroccan_affiliations = data_affiliation_author[data_affiliation_author['affiliation'].str.contains('Morocco', case=False)]

# %% [markdown]
# **2. Exctract  affiliations based on 'University' word including this word in diffrent languages using the following regular expression:**

# %%
# Pre-compile the regex pattern for efficiency
pattern = re.compile(r"([^,]*?)\s*(university|université|universidad)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)

# Function to extract the full university name
def extract_university_name(affiliation):
    match = pattern.search(affiliation)
    if match:
        # Concatenate the full university name by combining matched groups
        university_name = f"{match.group(1).strip()} {match.group(2).strip()} {match.group(3).strip()}"
        return university_name.strip()  # Remove any leading or trailing spaces
    else:
        return "Unknown"

# Apply the extraction function to the affiliation column
moroccan_affiliations['university_name'] = moroccan_affiliations['affiliation'].apply(extract_university_name)
# Out:
# <ipython-input-8-77663aca5f54>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moroccan_affiliations['university_name'] = moroccan_affiliations['affiliation'].apply(extract_university_name)

# %% [markdown]
# The results:

# %%
moroccan_affiliations
# Out:
#                                                 affiliation          author  \
# 0         Département de Cardiologie, Hôpital Universita...        Rahmi M.
# 1         Département de Cardiologie, Hôpital Universita...      Merzouk F.
# 2         Département de Cardiologie, Hôpital Universita...  El Ouarradi A.
# 3         Département de Cardiologie, Hôpital Universita...       Habbal R.
# 253       Laboratoire de Matière Condensée et Sciences I...       Sabbah H.
# ...                                                     ...             ...
# 10432479  Laboratory of Biotechnology and Valorization o...   El Moznine R.
# 10432480  Laboratory of Biotechnology and Valorization o...      Monkade M.
# 10432481  Laboratory of Biotechnology and Valorization o...         Zaim S.
# 10432482  Laboratory of Biotechnology and Valorization o...        Nmila R.
# 10432483  Laboratory of Biotechnology and Valorization o...        Rchid H.
#
#          affiliation_id                 university_name
# 0                     1                         Unknown
# 1                     1                         Unknown
# 2                     1                         Unknown
# 3                     1                         Unknown
# 253                   3  Mohammed V University in Rabat
# ...                 ...                             ...
# 10432479          44604     Chouaib Doukkali University
# 10432480          44604     Chouaib Doukkali University
# 10432481          44604     Chouaib Doukkali University
# 10432482          44604     Chouaib Doukkali University
# 10432483          44604     Chouaib Doukkali University
#
# [361528 rows x 4 columns]

# %% [markdown]
# Save known affiliations

# %%
known_moroccan_affiliations=moroccan_affiliations[moroccan_affiliations["university_name"]!='Unknown']

# %%
known_moroccan_affiliations.to_csv('/content/drive/MyDrive/data2024/Not_Unkown_moroccan_affiliations.csv')

# %% [markdown]
# **3. Exctract 'Unkown' affiliations then apply the  regular expression:**

# %%
Unkown_moroccan_affiliations=moroccan_affiliations[moroccan_affiliations["university_name"]=='Unknown']

# %%
Unkown_moroccan_affiliations
# Out:
#                                                 affiliation          author  \
# 0         Département de Cardiologie, Hôpital Universita...        Rahmi M.
# 1         Département de Cardiologie, Hôpital Universita...      Merzouk F.
# 2         Département de Cardiologie, Hôpital Universita...  El Ouarradi A.
# 3         Département de Cardiologie, Hôpital Universita...       Habbal R.
# 837               Independent Scientist, Marrakech, Morocco       Taoudi Y.
# ...                                                     ...             ...
# 10432008  Hassan II Agronomy and Veterinary Institute, H...    Elqarnifa S.
# 10432009  Hassan II Agronomy and Veterinary Institute, H...        Lasky M.
# 10432010  Hassan II Agronomy and Veterinary Institute, H...  Ait-Oubahou A.
# 10432011  Hassan II Agronomy and Veterinary Institute, H...     Benichou M.
# 10432012  Hassan II Agronomy and Veterinary Institute, H...   Abderrazik M.
#
#          affiliation_id university_name
# 0                     1         Unknown
# 1                     1         Unknown
# 2                     1         Unknown
# 3                     1         Unknown
# 837                  17         Unknown
# ...                 ...             ...
# 10432008          44547         Unknown
# 10432009          44547         Unknown
# 10432010          44547         Unknown
# 10432011          44547         Unknown
# 10432012          44547         Unknown
#
# [42534 rows x 4 columns]

# %% [markdown]
# The percentage of unknown is :

# %%
(56907/7882778)*100
# Out:
# 0.7219155480466404

# %% [markdown]
# The percentage is 0.72 %

# %%
import re
# Pre-compile the regex pattern for efficiency
pattern = re.compile(r"([^,]*?)\s*(institute|institut|academy|school|college|polytechnic|center|centre|centro|conservatory|organization|corporation|association|Hospital|INPT)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)

# Function to extract the full university name
def extract_university_name(affiliation):
    match = pattern.search(affiliation)
    if match:
        # Concatenate the full university name by combining matched groups
        university_name = f"{match.group(1).strip()} {match.group(2).strip()} {match.group(3).strip()}"
        return university_name.strip()  # Remove any leading or trailing spaces
    else:
        return "Unknown"

# Apply the extraction function to the affiliation column
Unkown_moroccan_affiliations['university_name'] = Unkown_moroccan_affiliations['affiliation'].apply(extract_university_name)
# Out:
# <ipython-input-14-385a73855858>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Unkown_moroccan_affiliations['university_name'] = Unkown_moroccan_affiliations['affiliation'].apply(extract_university_name)

# %% [markdown]
# The results:

# %%
Unkown_moroccan_affiliations
# Out:
#                                                 affiliation          author  \
# 0         Département de Cardiologie, Hôpital Universita...        Rahmi M.
# 1         Département de Cardiologie, Hôpital Universita...      Merzouk F.
# 2         Département de Cardiologie, Hôpital Universita...  El Ouarradi A.
# 3         Département de Cardiologie, Hôpital Universita...       Habbal R.
# 837               Independent Scientist, Marrakech, Morocco       Taoudi Y.
# ...                                                     ...             ...
# 10432008  Hassan II Agronomy and Veterinary Institute, H...    Elqarnifa S.
# 10432009  Hassan II Agronomy and Veterinary Institute, H...        Lasky M.
# 10432010  Hassan II Agronomy and Veterinary Institute, H...  Ait-Oubahou A.
# 10432011  Hassan II Agronomy and Veterinary Institute, H...     Benichou M.
# 10432012  Hassan II Agronomy and Veterinary Institute, H...   Abderrazik M.
#
#          affiliation_id                              university_name
# 0                     1                                      Unknown
# 1                     1                                      Unknown
# 2                     1                                      Unknown
# 3                     1                                      Unknown
# 837                  17                                      Unknown
# ...                 ...                                          ...
# 10432008          44547  Hassan II Agronomy and Veterinary Institute
# 10432009          44547  Hassan II Agronomy and Veterinary Institute
# 10432010          44547  Hassan II Agronomy and Veterinary Institute
# 10432011          44547  Hassan II Agronomy and Veterinary Institute
# 10432012          44547  Hassan II Agronomy and Veterinary Institute
#
# [42534 rows x 4 columns]

# %%
known_moroccan_affiliations=Unkown_moroccan_affiliations[Unkown_moroccan_affiliations["university_name"]!='Unknown']

# %%
len(Unkown_moroccan_affiliations)
# Out:
# 42534

# %%
len(Unkown_moroccan_affiliations[Unkown_moroccan_affiliations["university_name"]=='Unknown'])
# Out:
# 16646

# %% [markdown]
# The percentage again of Unknown affiliations is

# %%
16646/42534
# Out:
# 0.3913575022335073

# %%
known_moroccan_affiliations.to_csv('/content/drive/MyDrive/data2024/Unkown_moroccan_affiliations.csv')

# %% [markdown]
# ## **STEP 2:**

# %% [markdown]
# **1. Exctract non moroccan affiliations based on 'Morocco' country means whene country != 'Morocco'.**

# %%
# Select rows where 'affiliation' does not contain 'Morocco'
non_moroccan_affiliations = data_affiliation_author[~data_affiliation_author['affiliation'].str.contains('Morocco', case=False, na=False)]

# %% [markdown]
# **2. Exctract  affiliations based on 'University' word including this word in diffrent languages using the following regular expression:**

# %%
non_moroccan_affiliations.isna().sum()
# Out:
# affiliation       0
# author            0
# affiliation_id    0
# dtype: int64

# %% [markdown]
# Let's replace the null values with ' '

# %%
non_moroccan_affiliations['affiliation'] = non_moroccan_affiliations['affiliation'].fillna('').astype(str)
# Out:
# <ipython-input-23-ed86f8ecfb61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_moroccan_affiliations['affiliation'] = non_moroccan_affiliations['affiliation'].fillna('').astype(str)

# %%
print(non_moroccan_affiliations['affiliation'].dtype)
# Out:
# object

# %%
non_moroccan_affiliations
# Out:
#                                                 affiliation        author  \
# 4         College of Engineering and Technology, America...     Sabbah H.
# 5         College of Engineering and Technology, America...      Fadil Z.
# 6         College of Engineering and Technology, America...    El Fdil R.
# 7         College of Engineering and Technology, America...      Kim S.C.
# 8         College of Engineering and Technology, America...  Raorane C.J.
# ...                                                     ...           ...
# 10432494  School of Plant Biology, Faculty of Science, T...      Bitew B.
# 10432495  School of Plant Biology, Faculty of Science, T...    Fininsa C.
# 10432496  School of Plant Biology, Faculty of Science, T...     Terefe H.
# 10432497  School of Plant Biology, Faculty of Science, T...   Barbetti M.
# 10432498  School of Plant Biology, Faculty of Science, T...      Ahmed S.
#
#          affiliation_id
# 4                     2
# 5                     2
# 6                     2
# 7                     2
# 8                     2
# ...                 ...
# 10432494          44607
# 10432495          44607
# 10432496          44607
# 10432497          44607
# 10432498          44607
#
# [10070971 rows x 3 columns]

# %%
import re
# Pre-compile the regex pattern for efficiency
pattern = re.compile(r"([^,]*?)\s*(university|université|universidad|universiti)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)

# Function to extract the full university name
def extract_university_name(affiliation):
    match = pattern.search(affiliation)
    if match:
        # Concatenate the full university name by combining matched groups
        university_name = f"{match.group(1).strip()} {match.group(2).strip()} {match.group(3).strip()}"
        return university_name.strip()  # Remove any leading or trailing spaces
    else:
        return "Unknown"

# Apply the extraction function to the affiliation column
non_moroccan_affiliations['university_name'] = non_moroccan_affiliations['affiliation'].apply(extract_university_name)
# Out:
# <ipython-input-26-e0ae3a2ee87b>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_moroccan_affiliations['university_name'] = non_moroccan_affiliations['affiliation'].apply(extract_university_name)

# %% [markdown]
# The results:

# %%
non_moroccan_affiliations
# Out:
#                                                 affiliation        author  \
# 4         College of Engineering and Technology, America...     Sabbah H.
# 5         College of Engineering and Technology, America...      Fadil Z.
# 6         College of Engineering and Technology, America...    El Fdil R.
# 7         College of Engineering and Technology, America...      Kim S.C.
# 8         College of Engineering and Technology, America...  Raorane C.J.
# ...                                                     ...           ...
# 10432494  School of Plant Biology, Faculty of Science, T...      Bitew B.
# 10432495  School of Plant Biology, Faculty of Science, T...    Fininsa C.
# 10432496  School of Plant Biology, Faculty of Science, T...     Terefe H.
# 10432497  School of Plant Biology, Faculty of Science, T...   Barbetti M.
# 10432498  School of Plant Biology, Faculty of Science, T...      Ahmed S.
#
#          affiliation_id                         university_name
# 4                     2  American University of the Middle East
# 5                     2  American University of the Middle East
# 6                     2  American University of the Middle East
# 7                     2  American University of the Middle East
# 8                     2  American University of the Middle East
# ...                 ...                                     ...
# 10432494          44607     The University of Western Australia
# 10432495          44607     The University of Western Australia
# 10432496          44607     The University of Western Australia
# 10432497          44607     The University of Western Australia
# 10432498          44607     The University of Western Australia
#
# [10070971 rows x 4 columns]

# %% [markdown]
# Save known affiliations

# %%
known_affiliations=non_moroccan_affiliations[non_moroccan_affiliations["university_name"]!='Unknown']

# %%
known_affiliations.to_csv("/content/drive/MyDrive/data2024/known_affiliations.csv", index=False)

# %% [markdown]
# **3. Exctract 'Unkown' affiliations then apply the  regular expression:**

# %%
Unknown_affiliations=non_moroccan_affiliations[non_moroccan_affiliations["university_name"]=='Unknown']

# %%
Unknown_affiliations
# Out:
#                                                 affiliation          author  \
# 890          INRAE, UR RiverLy, Villeurbanne, 69625, France    Ba-Haddou H.
# 891          INRAE, UR RiverLy, Villeurbanne, 69625, France      Taoussi O.
# 892          INRAE, UR RiverLy, Villeurbanne, 69625, France  Ait Lyazidi S.
# 893          INRAE, UR RiverLy, Villeurbanne, 69625, France      Coquery M.
# 894          INRAE, UR RiverLy, Villeurbanne, 69625, France       Masson M.
# ...                                                     ...             ...
# 10432484  Plant Protection, Debre Birhan Agricultural Re...        Bitew B.
# 10432485  Plant Protection, Debre Birhan Agricultural Re...      Fininsa C.
# 10432486  Plant Protection, Debre Birhan Agricultural Re...       Terefe H.
# 10432487  Plant Protection, Debre Birhan Agricultural Re...     Barbetti M.
# 10432488  Plant Protection, Debre Birhan Agricultural Re...        Ahmed S.
#
#          affiliation_id university_name
# 890                  19         Unknown
# 891                  19         Unknown
# 892                  19         Unknown
# 893                  19         Unknown
# 894                  19         Unknown
# ...                 ...             ...
# 10432484          44605         Unknown
# 10432485          44605         Unknown
# 10432486          44605         Unknown
# 10432487          44605         Unknown
# 10432488          44605         Unknown
#
# [3777733 rows x 4 columns]

# %%
import re
# Pre-compile the regex pattern for efficiency
pattern = re.compile(r"([^,]*?)\s*(institute|institut|academy|school|college|polytechnic|center|centre|centro|conservatory|organization|corporation|association|Hospital|INPT)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)

# Function to extract the full university name
def extract_university_name(affiliation):
    match = pattern.search(affiliation)
    if match:
        # Concatenate the full university name by combining matched groups
        university_name = f"{match.group(1).strip()} {match.group(2).strip()} {match.group(3).strip()}"
        return university_name.strip()  # Remove any leading or trailing spaces
    else:
        return "Unknown"

# Apply the extraction function to the affiliation column
Unknown_affiliations['university_name'] = Unknown_affiliations['affiliation'].apply(extract_university_name)
# Out:
# <ipython-input-32-f6696d4a19fb>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Unknown_affiliations['university_name'] = Unknown_affiliations['affiliation'].apply(extract_university_name)

# %% [markdown]
# The results:

# %%
Unknown_affiliations
# Out:
#                                                 affiliation          author  \
# 890          INRAE, UR RiverLy, Villeurbanne, 69625, France    Ba-Haddou H.
# 891          INRAE, UR RiverLy, Villeurbanne, 69625, France      Taoussi O.
# 892          INRAE, UR RiverLy, Villeurbanne, 69625, France  Ait Lyazidi S.
# 893          INRAE, UR RiverLy, Villeurbanne, 69625, France      Coquery M.
# 894          INRAE, UR RiverLy, Villeurbanne, 69625, France       Masson M.
# ...                                                     ...             ...
# 10432484  Plant Protection, Debre Birhan Agricultural Re...        Bitew B.
# 10432485  Plant Protection, Debre Birhan Agricultural Re...      Fininsa C.
# 10432486  Plant Protection, Debre Birhan Agricultural Re...       Terefe H.
# 10432487  Plant Protection, Debre Birhan Agricultural Re...     Barbetti M.
# 10432488  Plant Protection, Debre Birhan Agricultural Re...        Ahmed S.
#
#          affiliation_id                            university_name
# 890                  19                                    Unknown
# 891                  19                                    Unknown
# 892                  19                                    Unknown
# 893                  19                                    Unknown
# 894                  19                                    Unknown
# ...                 ...                                        ...
# 10432484          44605  Debre Birhan Agricultural Research Center
# 10432485          44605  Debre Birhan Agricultural Research Center
# 10432486          44605  Debre Birhan Agricultural Research Center
# 10432487          44605  Debre Birhan Agricultural Research Center
# 10432488          44605  Debre Birhan Agricultural Research Center
#
# [3777733 rows x 4 columns]

# %%
known_affiliations_2=Unknown_affiliations[Unknown_affiliations["university_name"]!='Unknown']

# %%
len(Unknown_affiliations)
# Out:
# 3777733

# %%
Unknown_affiliationsversion2=Unknown_affiliations[Unknown_affiliations["university_name"]=='Unknown']

# %%
len(Unknown_affiliationsversion2)
# Out:
# 1887423

# %%
known_affiliations_2
# Out:
#                                                 affiliation            author  \
# 924       Department of Chemical Engineering, Indian Ins...           Jose D.
# 925       Department of Chemical Engineering, Indian Ins...      Vasudevan S.
# 926       Department of Chemical Engineering, Indian Ins...  Venkatachalam P.
# 927       Department of Chemical Engineering, Indian Ins...        Maity S.K.
# 928       Department of Chemical Engineering, Indian Ins...    Septevani A.A.
# ...                                                     ...               ...
# 10432484  Plant Protection, Debre Birhan Agricultural Re...          Bitew B.
# 10432485  Plant Protection, Debre Birhan Agricultural Re...        Fininsa C.
# 10432486  Plant Protection, Debre Birhan Agricultural Re...         Terefe H.
# 10432487  Plant Protection, Debre Birhan Agricultural Re...       Barbetti M.
# 10432488  Plant Protection, Debre Birhan Agricultural Re...          Ahmed S.
#
#          affiliation_id                            university_name
# 924                  23   Indian Institute of Technology Hyderabad
# 925                  23   Indian Institute of Technology Hyderabad
# 926                  23   Indian Institute of Technology Hyderabad
# 927                  23   Indian Institute of Technology Hyderabad
# 928                  23   Indian Institute of Technology Hyderabad
# ...                 ...                                        ...
# 10432484          44605  Debre Birhan Agricultural Research Center
# 10432485          44605  Debre Birhan Agricultural Research Center
# 10432486          44605  Debre Birhan Agricultural Research Center
# 10432487          44605  Debre Birhan Agricultural Research Center
# 10432488          44605  Debre Birhan Agricultural Research Center
#
# [1890310 rows x 4 columns]

# %% [markdown]
# The problem:
#
# some universities can have diffrent names but still the same university

# %%
known_affiliations_2.to_csv('/content/drive/MyDrive/data2024/known_affiliations_2.csv')
