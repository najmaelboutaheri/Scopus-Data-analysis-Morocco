# %% [markdown]
# In this notebook we are going to combine the all dataset in one file csv.
# so we can easily apply all the preprocessing steps from cleaning to modeling.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
firstdataset= pd.read_csv("/content/drive/MyDrive/Data-Scopus/DataSample/Not_Unkown_moroccan_affiliations.csv")
seconddataset= pd.read_csv("/content/drive/MyDrive/Data-Scopus/DataSample/Unkown_moroccan_affiliations.csv")
thirddataset= pd.read_csv("/content/drive/MyDrive/Data-Scopus/DataSample/known_affiliations.csv")
fourthdataset= pd.read_csv("/content/drive/MyDrive/Data-Scopus/DataSample/known_affiliations_2.csv")

# %%
firstdataset.drop(columns=['Unnamed: 0'],inplace=True)
seconddataset.drop(columns=['Unnamed: 0'],inplace=True)
fourthdataset.drop(columns=['Unnamed: 0'],inplace=True)

# %%
firstdataset
# Out:
#                                               affiliation        author  \
# 0       Laboratory of Biochemistry and Molecular Genet...    Ouassou M.
# 1       Laboratory of Biochemistry and Molecular Genet...  Mukhaimar M.
# 2       Laboratory of Biochemistry and Molecular Genet...  El Amrani A.
# 3       Laboratory of Biochemistry and Molecular Genet...   Kroymann J.
# 4       Laboratory of Biochemistry and Molecular Genet...   Chauveau O.
# ...                                                   ...           ...
# 143158  Department of intensive care unit, Maternity S...      Etber A.
# 143159  Department of intensive care unit, Maternity S...    Errmili K.
# 143160  Department of intensive care unit, Maternity S...   Khairoun S.
# 143161  Department of intensive care unit, Maternity S...    Zeraidi N.
# 143162  Department of intensive care unit, Maternity S...    Baidada A.
#
#         affiliation_id                      university_name
# ...

# %%
seconddataset
# Out:
#                                              affiliation             author  \
# 0      Research Institute for Solar Energy and New En...          Touili S.
# 1      Research Institute for Solar Energy and New En...  Alami Merrouni A.
# 2      Research Institute for Solar Energy and New En...    El Hassouani Y.
# 3      Research Institute for Solar Energy and New En...      Bennouna E.G.
# 4      Research Institute for Solar Energy and New En...       Ghennioui A.
# ...                                                  ...                ...
# 10347  Regional Agricultural Research Center of Tadla...           Bouda S.
# 10348  Regional Agricultural Research Center of Tadla...           Adiba A.
# 10349  Regional Agricultural Research Center of Tadla...     Boutagayout A.
# 10350  Regional Agricultural Research Center of Tadla...        Kouighat M.
# 10351  Regional Agricultural Research Center of Tadla...          Razouk R.
#
# ...

# %%
thirddataset
# Out:
#                                                affiliation          author  \
# 0        Unité « Écologie, systématique et évolution »,...      Ouassou M.
# 1        Unité « Écologie, systématique et évolution »,...    Mukhaimar M.
# 2        Unité « Écologie, systématique et évolution »,...    El Amrani A.
# 3        Unité « Écologie, systématique et évolution »,...     Kroymann J.
# 4        Unité « Écologie, systématique et évolution »,...     Chauveau O.
# ...                                                    ...             ...
# 3414768  Department of Information Technology, College ...       Azrour M.
# 3414769  Department of Information Technology, College ...   El Allaoui A.
# 3414770  Department of Information Technology, College ...      Guezzaz A.
# 3414771  Department of Information Technology, College ...  Alabdulatif A.
# 3414772  Department of Information Technology, College ...      Alnajim A.
#
#          affiliation_id       university_name
# ...

# %%
fourthdataset
# Out:
#                                                affiliation        author  \
# 0        National Agricultural Research Center (NARC)–J...    Ouassou M.
# 1        National Agricultural Research Center (NARC)–J...  Mukhaimar M.
# 2        National Agricultural Research Center (NARC)–J...  El Amrani A.
# 3        National Agricultural Research Center (NARC)–J...   Kroymann J.
# 4        National Agricultural Research Center (NARC)–J...   Chauveau O.
# ...                                                    ...           ...
# 1091147  Dr. A. P. J. Abdul Kalam Research Lab, Departm...      Riadi Y.
# 1091148  Dr. A. P. J. Abdul Kalam Research Lab, Departm...         MK K.
# 1091149  Dr. A. P. J. Abdul Kalam Research Lab, Departm...    Oubella A.
# 1091150  Dr. A. P. J. Abdul Kalam Research Lab, Departm...   Itto M.Y.A.
# 1091151  Dr. A. P. J. Abdul Kalam Research Lab, Departm...    Auhmani A.
#
#          affiliation_id                                    university_name
# ...

# %%
firstdataset.info()
seconddataset.info()
thirddataset.info()
fourthdataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143163 entries, 0 to 143162
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   affiliation      143163 non-null  object
#  1   author           143163 non-null  object
#  2   affiliation_id   143163 non-null  int64
#  3   university_name  143163 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 4.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10352 entries, 0 to 10351
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   affiliation      10352 non-null  object
#  1   author           10352 non-null  object
#  2   affiliation_id   10352 non-null  int64
#  3   university_name  10352 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 323.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3414773 entries, 0 to 3414772
# ...

# %%
# Combine the datasets
affiliation_combined_dataset = pd.concat([firstdataset, seconddataset, thirddataset,fourthdataset], ignore_index=True)

# Display information about the combined dataset
affiliation_combined_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4659440 entries, 0 to 4659439
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   affiliation      object
#  1   author           object
#  2   affiliation_id   int64
#  3   university_name  object
# dtypes: int64(1), object(3)
# memory usage: 142.2+ MB

# %%
affiliation_combined_dataset.to_csv('/content/drive/MyDrive/Data-Scopus/DataSample/affiliation_combined_dataset.csv',index=False)
