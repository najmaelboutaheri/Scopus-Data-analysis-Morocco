# %% [markdown]
# In this notebook we are going to combine the all dataset in one file csv.
# so we can easily apply all the preprocessing steps from cleaning to modeling.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
firstdataset= pd.read_csv("/content/drive/MyDrive/data2024/Not_Unkown_moroccan_affiliations.csv")
seconddataset= pd.read_csv("/content/drive/MyDrive/data2024/Unkown_moroccan_affiliations.csv")
thirddataset= pd.read_csv("/content/drive/MyDrive/data2024/known_affiliations.csv")
fourthdataset= pd.read_csv("/content/drive/MyDrive/data2024/known_affiliations_2.csv")

# %%
firstdataset.drop(columns=['Unnamed: 0'],inplace=True)
seconddataset.drop(columns=['Unnamed: 0'],inplace=True)
fourthdataset.drop(columns=['Unnamed: 0'],inplace=True)

# %%
firstdataset
# Out:
#                                               affiliation         author  \
# 0       Laboratoire de Matière Condensée et Sciences I...      Sabbah H.
# 1       Laboratoire de Matière Condensée et Sciences I...       Fadil Z.
# 2       Laboratoire de Matière Condensée et Sciences I...     El Fdil R.
# 3       Laboratoire de Matière Condensée et Sciences I...       Kim S.C.
# 4       Laboratoire de Matière Condensée et Sciences I...   Raorane C.J.
# ...                                                   ...            ...
# 318989  Laboratory of Biotechnology and Valorization o...  El Moznine R.
# 318990  Laboratory of Biotechnology and Valorization o...     Monkade M.
# 318991  Laboratory of Biotechnology and Valorization o...        Zaim S.
# 318992  Laboratory of Biotechnology and Valorization o...       Nmila R.
# 318993  Laboratory of Biotechnology and Valorization o...       Rchid H.
#
#         affiliation_id                 university_name
# 0                    3  Mohammed V University in Rabat
# 1                    3  Mohammed V University in Rabat
# 2                    3  Mohammed V University in Rabat
# 3                    3  Mohammed V University in Rabat
# 4                    3  Mohammed V University in Rabat
# ...                ...                             ...
# 318989           44604     Chouaib Doukkali University
# 318990           44604     Chouaib Doukkali University
# 318991           44604     Chouaib Doukkali University
# 318992           44604     Chouaib Doukkali University
# 318993           44604     Chouaib Doukkali University
#
# [318994 rows x 4 columns]

# %%
seconddataset
# Out:
#                                              affiliation          author  \
# 0      High Institute of Nursing Professions and Heal...   Chouikh N.-E.
# 1      High Institute of Nursing Professions and Heal...     Alahyane H.
# 2      High Institute of Nursing Professions and Heal...       Mounir A.
# 3      High Institute of Nursing Professions and Heal...   El Hachimi Y.
# 4      High Institute of Nursing Professions and Heal...     Cheggour M.
# ...                                                  ...             ...
# 25883  Hassan II Agronomy and Veterinary Institute, H...    Elqarnifa S.
# 25884  Hassan II Agronomy and Veterinary Institute, H...        Lasky M.
# 25885  Hassan II Agronomy and Veterinary Institute, H...  Ait-Oubahou A.
# 25886  Hassan II Agronomy and Veterinary Institute, H...     Benichou M.
# 25887  Hassan II Agronomy and Veterinary Institute, H...   Abderrazik M.
#
#        affiliation_id                                    university_name
# 0                  29  High Institute of Nursing Professions and Heal...
# 1                  29  High Institute of Nursing Professions and Heal...
# 2                  29  High Institute of Nursing Professions and Heal...
# 3                  29  High Institute of Nursing Professions and Heal...
# 4                  29  High Institute of Nursing Professions and Heal...
# ...               ...                                                ...
# 25883           44547        Hassan II Agronomy and Veterinary Institute
# 25884           44547        Hassan II Agronomy and Veterinary Institute
# 25885           44547        Hassan II Agronomy and Veterinary Institute
# 25886           44547        Hassan II Agronomy and Veterinary Institute
# 25887           44547        Hassan II Agronomy and Veterinary Institute
#
# [25888 rows x 4 columns]

# %%
thirddataset
# Out:
#                                                affiliation        author  \
# 0        College of Engineering and Technology, America...     Sabbah H.
# 1        College of Engineering and Technology, America...      Fadil Z.
# 2        College of Engineering and Technology, America...    El Fdil R.
# 3        College of Engineering and Technology, America...      Kim S.C.
# 4        College of Engineering and Technology, America...  Raorane C.J.
# ...                                                    ...           ...
# 6293233  School of Plant Biology, Faculty of Science, T...      Bitew B.
# 6293234  School of Plant Biology, Faculty of Science, T...    Fininsa C.
# 6293235  School of Plant Biology, Faculty of Science, T...     Terefe H.
# 6293236  School of Plant Biology, Faculty of Science, T...   Barbetti M.
# 6293237  School of Plant Biology, Faculty of Science, T...      Ahmed S.
#
#          affiliation_id                         university_name
# 0                     2  American University of the Middle East
# 1                     2  American University of the Middle East
# 2                     2  American University of the Middle East
# 3                     2  American University of the Middle East
# 4                     2  American University of the Middle East
# ...                 ...                                     ...
# 6293233           44607     The University of Western Australia
# 6293234           44607     The University of Western Australia
# 6293235           44607     The University of Western Australia
# 6293236           44607     The University of Western Australia
# 6293237           44607     The University of Western Australia
#
# [6293238 rows x 4 columns]

# %%
fourthdataset
# Out:
#                                                affiliation            author  \
# 0        Department of Chemical Engineering, Indian Ins...           Jose D.
# 1        Department of Chemical Engineering, Indian Ins...      Vasudevan S.
# 2        Department of Chemical Engineering, Indian Ins...  Venkatachalam P.
# 3        Department of Chemical Engineering, Indian Ins...        Maity S.K.
# 4        Department of Chemical Engineering, Indian Ins...    Septevani A.A.
# ...                                                    ...               ...
# 1890305  Plant Protection, Debre Birhan Agricultural Re...          Bitew B.
# 1890306  Plant Protection, Debre Birhan Agricultural Re...        Fininsa C.
# 1890307  Plant Protection, Debre Birhan Agricultural Re...         Terefe H.
# 1890308  Plant Protection, Debre Birhan Agricultural Re...       Barbetti M.
# 1890309  Plant Protection, Debre Birhan Agricultural Re...          Ahmed S.
#
#          affiliation_id                            university_name
# 0                    23   Indian Institute of Technology Hyderabad
# 1                    23   Indian Institute of Technology Hyderabad
# 2                    23   Indian Institute of Technology Hyderabad
# 3                    23   Indian Institute of Technology Hyderabad
# 4                    23   Indian Institute of Technology Hyderabad
# ...                 ...                                        ...
# 1890305           44605  Debre Birhan Agricultural Research Center
# 1890306           44605  Debre Birhan Agricultural Research Center
# 1890307           44605  Debre Birhan Agricultural Research Center
# 1890308           44605  Debre Birhan Agricultural Research Center
# 1890309           44605  Debre Birhan Agricultural Research Center
#
# [1890310 rows x 4 columns]

# %%
firstdataset.info()
seconddataset.info()
thirddataset.info()
fourthdataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318994 entries, 0 to 318993
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   affiliation      318994 non-null  object
#  1   author           318994 non-null  object
#  2   affiliation_id   318994 non-null  int64
#  3   university_name  318994 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 9.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25888 entries, 0 to 25887
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   affiliation      25888 non-null  object
#  1   author           25888 non-null  object
#  2   affiliation_id   25888 non-null  int64
#  3   university_name  25888 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 809.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6293238 entries, 0 to 6293237
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   affiliation      object
#  1   author           object
#  2   affiliation_id   int64
#  3   university_name  object
# dtypes: int64(1), object(3)
# memory usage: 192.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1890310 entries, 0 to 1890309
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   affiliation      object
#  1   author           object
#  2   affiliation_id   int64
#  3   university_name  object
# dtypes: int64(1), object(3)
# memory usage: 57.7+ MB

# %%
# Combine the datasets
affiliation_combined_dataset = pd.concat([firstdataset, seconddataset, thirddataset,fourthdataset], ignore_index=True)

# Display information about the combined dataset
affiliation_combined_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8528430 entries, 0 to 8528429
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   affiliation      object
#  1   author           object
#  2   affiliation_id   int64
#  3   university_name  object
# dtypes: int64(1), object(3)
# memory usage: 260.3+ MB

# %%
affiliation_combined_dataset.to_csv('/content/drive/MyDrive/data2024/affiliation_combined_dataset.csv',index=False)
