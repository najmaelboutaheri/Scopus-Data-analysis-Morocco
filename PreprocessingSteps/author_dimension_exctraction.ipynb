# %%
import pandas as pd

# %%
data_authors=pd.read_csv(r'/content/drive/MyDrive/data-new-scopus/author indexed.csv')

# %%
data_authors1=pd.read_csv(r'/content/drive/MyDrive/data-new-scopus/full name indexed.csv')

# %%
data_authors1=pd.read_csv(r'/content/drive/MyDrive/data-new-scopus/full name indexed.csv')

# %%
data_authors
# Out:
#        author_Authors  author_Index
# 0            Ardid S.         83531
# 1        Ducoin J.-G.         83608
# 2        Dvornický R.         83609
# 3           Veutro A.         83784
# 4         A Juhany K.         85444
# ...               ...           ...
# 95891      Zoulati M.          8308
# 95892     Zouraq S.A.         38670
# 95893       Zraidi M.         53490
# 95894        Zriaa R.         24081
# 95895      Zzeyani S.         10185
#
# [95896 rows x 2 columns]

# %%
# Remove duplicates based on the 'author_Authors' column
data_unique = data_authors.drop_duplicates(subset='author_Authors')
# Add a unique ID column
data_unique['unique_id'] = range(1, len(data_unique) + 1)
# Out:
# <ipython-input-4-97bf7a97b2c9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_unique['unique_id'] = range(1, len(data_unique) + 1)

# %%
data_unique
# Out:
#        author_Authors  author_Index  unique_id
# 0            Ardid S.         83531          1
# 1        Ducoin J.-G.         83608          2
# 2        Dvornický R.         83609          3
# 3           Veutro A.         83784          4
# 4         A Juhany K.         85444          5
# ...               ...           ...        ...
# 95891      Zoulati M.          8308      33038
# 95892     Zouraq S.A.         38670      33039
# 95893       Zraidi M.         53490      33040
# 95894        Zriaa R.         24081      33041
# 95895      Zzeyani S.         10185      33042
#
# [33042 rows x 3 columns]

# %%
data_unique.to_csv(r'/content/drive/MyDrive/data-new-scopus/author-dim.csv')

# %%
# Create a mapping of affiliation_indexed_index to unique_id from DataFrame A
mapping = data_unique.set_index('author_Authors')['unique_id']

# Map the unique_id to DataFrame B based on affiliation_indexed_index
data_authors['unique_id'] = data_authors['author_Authors'].map(mapping)

data_authors
# Out:
#        author_Authors  author_Index  unique_id
# 0            Ardid S.         83531          1
# 1        Ducoin J.-G.         83608          2
# 2        Dvornický R.         83609          3
# 3           Veutro A.         83784          4
# 4         A Juhany K.         85444          5
# ...               ...           ...        ...
# 95891      Zoulati M.          8308      33038
# 95892     Zouraq S.A.         38670      33039
# 95893       Zraidi M.         53490      33040
# 95894        Zriaa R.         24081      33041
# 95895      Zzeyani S.         10185      33042
#
# [95896 rows x 3 columns]

# %%
data_authors.to_csv((r'/content/drive/MyDrive/data-new-scopus/author-fact-table.csv'))
