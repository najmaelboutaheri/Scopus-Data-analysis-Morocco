# %%
import pandas as pd

# %%
data_affiliations=pd.read_csv(r'/content/drive/MyDrive/data-new-scopus/affiliation indexed.csv')

# %%
data_affiliations
# Out:
#                affiliation_indexed_affiliation_extracted  \
# 0                                            A Renner L.
# 1                                          Abouelnaga S.
# 2                                             Ahallat M.
# 3                                            Akimov A.V.
# 4                                            Akimov A.V.
# ...                                                  ...
# 95891  ZiekenhuisNetwerkAntwerpen Stuivenberg, Antwer...
# 95892                                           Zimbabwe
# 95893  Zoology Department, Faculty of Science, Damiet...
# 95894  Zoology Department, Faculty of Science, Omar A...
# 95895  Zubov State Oceanographic Institute, Moscow, 1...
#
#        affiliation_indexed_index
# 0                          17315
# 1                          17362
# 2                           8360
# 3                          46029
# 4                          50307
# ...                          ...
# 95891                      26953
# ...

# %%
data_full_names=pd.read_csv(r'/content/drive/MyDrive/data-new-scopus/full name indexed.csv')

# %%
data_full_names
# Out:
#       full_name_author_Author_full_names  full_name_author_Index
# 0                              Ardid, S.                   83531
# 1                          Ducoin, J.-G.                   83608
# 2                          Dvornický, R.                   83609
# 3                             Veutro, A.                   83784
# 4                       A Juhany, Khalid                   85444
# ...                                  ...                     ...
# 95891                        Zoulati, M.                    8308
# 95892                Zouraq, Sara Azzabi                   38670
# 95893                    Zraidi, Mohamed                   53490
# 95894                       Zriaa, Rajae                   24081
# 95895                        Zzeyani, S.                   10185
#
# [95896 rows x 2 columns]

# %%
data=pd.read_csv(r'/content/drive/MyDrive/data-new-scopus/combined_sampled_data.csv')

# %%
data

# %%
data.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Affiliations',
#        'Authors with affiliations', 'Abstract', 'Author Keywords',
#        'Index Keywords', 'Molecular Sequence Numbers', 'Chemicals/CAS',
#        'Tradenames', 'Manufacturers', 'Funding Details', 'Funding Texts',
#        'References', 'Correspondence Address', 'Editors', 'Publisher',
#        'Sponsors', 'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
data['Affiliations'][]
# Out:
# 0       Unité « Écologie, systématique et évolution »,...
# 1       Laboratory of Informatics, Research Operationa...
# 2       Mohammed v University in Rabat, Morocco; Inter...
# 3       Abdelmalek Essaadi University, Faculty of Scie...
# 4       Team of Virology Oncology and Medical Biotechn...
#                               ...
# 6301    Laboratoire de Matière Condensée et Sciences I...
# 6302    National Institute of Agricultural Research (I...
# 6303    Gynaecology-Obstetrics and Endoscopy Departmen...
# 6304    Ibn Tofail University, Faculty of Sciences, Ke...
# 6305    Faculty of Science, Mohammed V University, Rab...
# Name: Affiliations, Length: 6306, dtype: object

# %%
import re

# %%
data_affiliations.columns
# Out:
# Index(['affiliation_indexed_affiliation_extracted', 'affiliation_indexed_index'], dtype='object')

# %%
# Pre-compile the regex pattern for efficiency
pattern = re.compile(r"([^,]*?)\s*(university|université|universidad)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)

# Function to extract the full university name
def extract_university_name(affiliation):
    match = pattern.search(affiliation)
    if match:
        # Concatenate the full university name by combining matched groups
        university_name = f"{match.group(1).strip()} {match.group(2).strip()} {match.group(3).strip()}"
        return university_name.strip()  # Remove any leading or trailing spaces
    else:
        return "Unknown"

# Apply the extraction function to the affiliation column
data_affiliations['university_name'] = data_affiliations['affiliation_indexed_affiliation_extracted'].apply(extract_university_name)

# %%
len(data_affiliations[data_affiliations["university_name"]=='Unknown'])
# Out:
# 57329

# %%
57329/95896
# Out:
# 0.597824726787353

# %%
import re
# Pre-compile the regex pattern for efficiency
pattern = re.compile(r"([^,]*?)\s*(university|université|universidad|institute|institut|academy|school|college|polytechnic|center|centre|centro|conservatory|organization|corporation|association|Hospital|INPT)[\s\-]*(.*?)(?=,|$)", re.IGNORECASE)

# Function to extract the full university name
def extract_university_name(affiliation):
    match = pattern.search(affiliation)
    if match:
        # Concatenate the full university name by combining matched groups
        university_name = f"{match.group(1).strip()} {match.group(2).strip()} {match.group(3).strip()}"
        return university_name.strip()  # Remove any leading or trailing spaces
    else:
        return "Unknown"

# Apply the extraction function to the affiliation column
data_affiliations['university_name'] = data_affiliations['affiliation_indexed_affiliation_extracted'].apply(extract_university_name)

# %%
data_affiliations
# Out:
#                affiliation_indexed_affiliation_extracted  \
# 0                                            A Renner L.
# 1                                          Abouelnaga S.
# 2                                             Ahallat M.
# 3                                            Akimov A.V.
# 4                                            Akimov A.V.
# ...                                                  ...
# 95891  ZiekenhuisNetwerkAntwerpen Stuivenberg, Antwer...
# 95892                                           Zimbabwe
# 95893  Zoology Department, Faculty of Science, Damiet...
# 95894  Zoology Department, Faculty of Science, Omar A...
# 95895  Zubov State Oceanographic Institute, Moscow, 1...
#
#        affiliation_indexed_index                      university_name
# 0                          17315                              Unknown
# 1                          17362                              Unknown
# ...

# %%
data_affiliations.to_csv(r'/content/drive/MyDrive/data-new-scopus/data_affiliations.csv')

# %%
len(data_affiliations[data_affiliations["university_name"]=='Unknown'])
# Out:
# 49947

# %%
data_affiliations1=data_affiliations

# %%
data_affiliations1
# Out:
#                affiliation_indexed_affiliation_extracted  \
# 0                                            A Renner L.
# 1                                          Abouelnaga S.
# 2                                             Ahallat M.
# 3                                            Akimov A.V.
# 4                                            Akimov A.V.
# ...                                                  ...
# 95891  ZiekenhuisNetwerkAntwerpen Stuivenberg, Antwer...
# 95892                                           Zimbabwe
# 95893  Zoology Department, Faculty of Science, Damiet...
# 95894  Zoology Department, Faculty of Science, Omar A...
# 95895  Zubov State Oceanographic Institute, Moscow, 1...
#
#        affiliation_indexed_index                      university_name
# 0                          17315                              Unknown
# 1                          17362                              Unknown
# ...

# %%
# Remove duplicates based on the 'university_name' column
data_unique = data_affiliations1.drop_duplicates(subset='university_name')
# Add a unique ID column
data_unique['unique_id'] = range(1, len(data_unique) + 1)
# Save the updated DataFrame back to a file (optional)
data_unique.to_csv("unique_affiliations.csv", index=False)

# %%
data_unique
# Out:
#                affiliation_indexed_affiliation_extracted  \
# 0                                            A Renner L.
# 307       "Evangelismos"General Hospital, Athens, Greece
# 308    "Iuliu Hațieganu" University of Medicine and P...
# 310    "September 21st"University of Medicine and App...
# 312    (LAMA), University of Fez, Department of Mathe...
# ...                                                  ...
# 95882  Zhongshan Affiliated Hospital, Dalian Universi...
# 95886     Ziauddin University Karachi, Karachi, Pakistan
# 95893  Zoology Department, Faculty of Science, Damiet...
# 95894  Zoology Department, Faculty of Science, Omar A...
# 95895  Zubov State Oceanographic Institute, Moscow, 1...
#
#        affiliation_indexed_index  \
# 0                          17315
# 307                        82003
# 308                         4967
# 310                        81979
# 312                        10292
# ...                          ...
# 95882                      27143
# ...

# %%
data_unique.drop(columns='affiliation_indexed_affiliation_extracted',inplace=True)
# Out:
# <ipython-input-46-461c48c9493f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_unique.drop(columns='affiliation_indexed_affiliation_extracted',inplace=True)

# %%
data_unique
# Out:
#        affiliation_indexed_index  \
# 0                          17315
# 307                        82003
# 308                         4967
# 310                        81979
# 312                        10292
# ...                          ...
# 95882                      27143
# 95886                      74002
# 95893                      14886
# 95894                      92345
# 95895                      22291
#
#                                          university_name  unique_id
# 0                                                Unknown          1
# 307                       "Evangelismos"General Hospital          2
# 308    "Iuliu Hațieganu" University of Medicine and P...          3
# 310    "September 21st" University of Medicine and Ap...          4
# 312                                    University of Fez          5
# ...                                                  ...        ...
# 95882                      Zhongshan Affiliated Hospital       7430
# ...

# %%
data_unique.to_csv('/content/drive/MyDrive/data-new-scopus/data_unique.csv', index=False)

# %%
# Create a mapping of affiliation_indexed_index to unique_id from DataFrame A
mapping = data_unique.set_index('university_name')['unique_id']

# Map the unique_id to DataFrame B based on affiliation_indexed_index
data_affiliations['unique_id'] = data_affiliations['university_name'].map(mapping)

# Save the updated DataFrame B to a new file (optional)
data_affiliations.to_csv("updated_file_b.csv", index=False)
data_affiliations
# Out:
#                affiliation_indexed_affiliation_extracted  \
# 0                                            A Renner L.
# 1                                          Abouelnaga S.
# 2                                             Ahallat M.
# 3                                            Akimov A.V.
# 4                                            Akimov A.V.
# ...                                                  ...
# 95891  ZiekenhuisNetwerkAntwerpen Stuivenberg, Antwer...
# 95892                                           Zimbabwe
# 95893  Zoology Department, Faculty of Science, Damiet...
# 95894  Zoology Department, Faculty of Science, Omar A...
# 95895  Zubov State Oceanographic Institute, Moscow, 1...
#
#        affiliation_indexed_index                      university_name  \
# 0                          17315                              Unknown
# 1                          17362                              Unknown
# ...

# %%
data_affiliations.isna().sum()
# Out:
# affiliation_indexed_affiliation_extracted    0
# affiliation_indexed_index                    0
# university_name                              0
# unique_id                                    0
# dtype: int64

# %%
data_affiliations.to_csv('/content/drive/MyDrive/data-new-scopus/affiliations_fact_table.csv')
